# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as dt

# %%
D = dt.load_iris()
D.keys()
print(D.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
x = D.data
y = D.target
np.unique(y)
print(y.shape)
print(x.shape)
plt.plot(y,'.')
plt.show()
# Out:
# (150,)
# (150, 4)

# %%
D2 = dt.load_diabetes()
y2 = D2.target
plt.plot(y2,'.')
plt.show()

# %%
#PERMITE BARALHAR OS NUMEROS PRETENDIDOS
#NAO HAVER REPTIÇÔES
rd= np.random
idx = rd.permutation(150)
rd.permutation(10)
plt.plot(idx,'.'), plt.show()
idx[:10]
# Out:
# array([ 98,  10,  80, 128,  60, 112,  66,  50,  64, 100])
